# %%
from IPython.display import Image

# %% [markdown]
# # Algoritmo Michael O. Rabin and Richard M. Karp 1987

# %% [markdown]
# # ¿Como Funciona?
#
# ### Naive + Comparacion Por Hash

# %%
Image("img/Rabin-Karp-Basic-Principles.png")

# %% [markdown]
# # Implementacion:

# %%
#Valor de hash del patron 
hPatternValue = H(P) 

# ciclo principal del algoritmo 
for j in xrange(t_len): 
    hStringValue = H(T[j:p_len + j]) 

    #si hay match 
    if (hPatternValue == hStringValue): 

        for i in xrange(p_len): 
            #se verifica letra por letra 
	matchs.append(j)

#Devolvemos la lista 
return matchs

# %% [markdown]
# # ¿Como mejorar la eficiencia?
#
# #### librería pyhash (https://github.com/flier/pyfasthash)
# #### implementaciones en C/C++ de algoritmos no criptograficos
# #### Todos de 32 bits: FNV, Murmur Hash, City Hash, Spooky Hash

# %% [markdown]
# # Complejidad:
#
# ### Mala funcion de hash-->O(mn)
# ### Buena funcion de hash-->O(m+n)

# %% [markdown]
# # Investigacion y Aplicaciones

# %% [markdown]
# ### Muy malo para string matching
#
# ### Muy bueno para multiple matching (beneficio de O(m+n))

# %%
Image("img/Application-of-Rabin-Karp.png")

# %% [markdown]
# # Recomendaciones a futuro
#
# ### Aplicar randomizado
#
# ### Usar Spooky
